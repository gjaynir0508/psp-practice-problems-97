# %%
# Q 15. Illustrate sets: insertion, removing, predefined operations
# A set is a collection which is unordered and unindexed and consists of unique elements (no duplicates).
#  In Python sets are written with curly brackets.
#  Create a Set:
thisset = {"apple", "banana", "cherry", "apple", "cherry"}
print(thisset)
# A set is mutable but it can only contain hashable objects.
# unhashable_set = {{"key": 2}, [4, 5, 6]} # TypeError: unhashable type: 'dict'

# set() constructor:
#  It is also possible to use the set() constructor to make a set.
#  Using the set() constructor to make a set:
thisset = set(["apple", "banana", "cherry"])
print(thisset)

#  Access Items:
#  You cannot access items in a set by referring to an index, since sets are unordered the items has no index.
#  But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.
#  Loop through the set, and print the values:
for x in thisset:
    print(x)

# Adding Items:
#  Once a set is created, you cannot change its items, but you can add new items.
#  To add one item to a set use the add() method.
#  To add more than one item to a set use the update() method.
# Example:
thisset.add("orange")
print(thisset)
#  Add multiple items to a set, using the update() method:
thisset.update(["orange", "mango", "grapes"])
print(thisset)


# Removing Items:
#  To remove an item in a set, use the remove(), or the discard() method.
#  Note: If the item to remove does not exist, remove() will raise an error.
#  Remove "banana" by using the remove() method:
thisset.remove("banana")
print(thisset)

#  Note: If the item to remove does not exist, discard() will NOT raise an error.
#  Remove "pear" by using the discard() method:
thisset.discard("pear")
print(thisset)


# Predefined Operations:
# 0. Length:
#  To determine how many items a set has, use the len() method.
print(f"{len(thisset) = }")

# 1. Membership Test:
#  Check if "banana" is present in the set:
print(f'{"banana" in thisset = }')

# 2. Sets' Mathematical Operations:
#   i. Union:
#     Return a set that contains all items from both set, duplicates are excluded:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)
# Note: Both union() and update() will exclude any duplicate items.
#   ii. Intersection:
#    Return a set that contains the items that exist in both set, duplicates are excluded:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3, "a", "b"}
set3 = set1.intersection(set2)
print(set3)
#   iii. Difference:
#    Return a set that contains the items that exist only in set1, and not in set2:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3, "a", "b"}
set3 = set1.difference(set2)
print(set3)
#   iv. Symmetric Difference:
#    Return a set that contains all items from both set, except items that are present in both sets:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3, "a", "b"}
set3 = set1.symmetric_difference(set2)
print(set3)

#   v. Subset:
#    Return True if all items in set1 are present in set2:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3, "a", "b", "c"}
is_subset = set1.issubset(set2)
print(is_subset)

#   vi. Superset:
#    Return True if all items in set2 are present in set1:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3, "a", "b", "c"}
is_superset = set1.issuperset(set2)
print(is_superset)

#   vii. Disjoint:
#    Return True if no items in set1 is present in set2:
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
is_disjoint = set1.isdisjoint(set2)
print(is_disjoint)

# Additionally, operators can be used to perform the same operations:
#   i. Union: | operator
#   ii. Intersection: & operator
#   iii. Difference: - operator
#   iv. Symmetric Difference: ^ operator
#   v. Subset: <= operator
#   vi. Superset: >= operator
#   vii. Strict Superset: > operator
#   viii. Strict Subset: < operator
# Out:
# {'banana', 'cherry', 'apple'}
# {'banana', 'cherry', 'apple'}
# banana
# cherry
# apple
# {'banana', 'cherry', 'orange', 'apple'}
# {'orange', 'banana', 'grapes', 'cherry', 'apple', 'mango'}
# {'orange', 'grapes', 'cherry', 'apple', 'mango'}
# {'orange', 'grapes', 'cherry', 'apple', 'mango'}
# len(thisset) = 5
# "banana" in thisset = False
# {1, 2, 3, 'b', 'a', 'c'}
# {'b', 'a'}
# {'c'}
# {1, 2, 3, 'c'}
# True
# False
# True
