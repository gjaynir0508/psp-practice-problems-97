# %%
# 19) Write a program to compute BMI of a person. Body mass index (BMI) is a
# person’s weight in kilograms divided by the square of height in meters.

import math
w, h = int(input("Weigth of person (in kgs)=")), float(
    input("Height of person (in meters)="))
print("Body mass index (BMI) of that person is =", (w)/(h**2))

# %%
# 20) Write a program to find areas of circle, rectangle and triangle:


a = int(input("Radius of circle="))
l1, b1 = int(input("length of rectangle=")), int(
    input("Breadth of rectangle="))
b, h = int(input("Base of triangle=")), int(input("Height of triangle="))

print("Area of circle =", math.pi*(a**2))
print("Area of rectangle =", l1*b1)
print("Area of triangle =", (1/2)*b*h)

# %%
# 21) Write a Program to find simple interest:

p, t, r = int(input("Principal amount=")), int(
    input("Time period=")), float(input("Rate of interest="))
print("Simple interest =", (p*t*r)/100)

# %%
# 22) Write a program to find roots of a quadratic equation :

a, b, c = int(input("Coefficient of x**2=")
              ), int(input("Coefficient of x=")), int(input("Constant="))
x, y = (-b+(b**2-(4*a*c))**0.5)/(2*a), (-b-(b**2-(4*a*c))**0.5)/(2*a)
print("Roots of (", a, "x**2+(", b, ")x+(", c, ") =", x, " & ", y)

# %%
# 23) Write a program to find whether a no. is even or odd :

a = int(input("Number="))
if a % 2 == 0:
    print("Even number")
else:
    print("Odd number")

# %%
# 24) Write a program to find whether a person is eligible to vote or not :

a = int(input("Age of person ( in years) ="))
if a >= 18:
    print("Person can vote")
else:
    print("Person can\'t vote")

# %%
# 25) Write a program to find biggest of two numbers :

a, b = int(input("Number 1 =")), int(input("Number 2 ="))
if a > b:
    print(a, "is biggest number")
elif a < b:
    print(b, "is biggest number")
else:
    print("Both are equal numbers")

# %%
# 26) Write a program to find biggest of three number without using logical operators :

a, b, c = int(input("Number1 =")), int(
    input("Number2 =")), int(input("Number3 ="))
if a != b != c:
    if a > b:
        if a > c:
            print(a, "is biggest number")
        else:
            print(c, "is biggest number")
    elif b > c:
        print(b, "is biggest number")
    else:
        print(c, "is biggest number")

elif a != b == c:
    if a > b:
        print(a, "is biggest number")
    else:
        print(b, "is biggest number")

elif a == b != c:
    if b > c:
        print(b, "is biggest number")
    else:
        print(c, "is biggest number")

elif b == c != a:
    if c > a:
        print(c, "is biggest number")
    else:
        print(a, "is biggest number")

else:
    print("All numbers are equal")

# %%
# 27) Write a program to find biggest of four number without using logical operators :

a, b, c, d = int(input("Number1 =")), int(input("Number2 =")), int(
    input("Number3 =")), int(input("Number4 ="))
if a != b != c != d:
    if a > b:
        if a > c:
            if a > d:
                print(a, "is biggest number")
            else:
                print(d, "is biggest number")
        elif c > d:
            print(c, "is biggest number")
        else:
            print(d, "is biggest number")
    else:
        if b > c:
            if b > d:
                print(b, "is biggest number")
            else:
                print(d, "is biggest number")
        elif c > d:
            print(c, "is biggest number")
        else:
            print(d, "is biggest number")

elif a != b != c == d:
    if a > b:
        if a > c:
            print(a, "is biggest number")
        else:
            print(c, "is biggest number")
    elif b > c:
        print(b, "is biggest number")
    else:
        print(c, "is biggest number")

elif a != c != b == d:
    if a > c:
        if a > b:
            print(a, "is biggest number")
        else:
            print(b, "is biggest number")
    elif c > b:
        print(c, "is biggest number")
    else:
        print(b, "is biggest number")

elif c != b != a == d:
    if c > b:
        if c > a:
            print(c, "is biggest number")
        else:
            print(a, "is biggest number")
    elif b > a:
        print(b, "is biggest number")
    else:
        print(a, "is biggest number")

elif a != d != b == c:
    if a > d:
        if a > b:
            print(a, "is biggest number")
        else:
            print(b, "is biggest number")
    elif d > b:
        print(d, "is biggest number")
    else:
        print(b, "is biggest number")

elif b != d != a == c:
    if b > d:
        if b > a:
            print(b, "is biggest number")
        else:
            print(a, "is biggest number")
    elif d > a:
        print(d, "is biggest number")
    else:
        print(a, "is biggest number")

elif c != d != a == b:
    if c > d:
        if c > a:
            print(c, "is biggest number")
        else:
            print(a, "is biggest number")
    elif d > a:
        print(d, "is biggest number")
    else:
        print(a, "is biggest number")

elif a != b == c == d:
    if a > b:
        print(a, "is biggest number")
    else:
        print(b, "is biggest number")

elif a != c == b == d:
    if a > c:
        print(a, "is biggest number")
    else:
        print(c, "is biggest number")

elif a != d == b == c:
    if a > d:
        print(a, "is biggest number")
    else:
        print(d, "is biggest number")

elif b != c == a == d:
    if b > c:
        print(b, "is biggest number")
    else:
        print(c, "is biggest number")

elif b != d == a == c:
    if b > d:
        print(b, "is biggest number")
    else:
        print(d, "is biggest number")

elif c != d == a == b:
    if c > d:
        print(c, "is biggest number")
    else:
        print(d, "is biggest number")

else:
    print("All are equal numbers")

# %%
# 28) Write a program to find biggest of three number using logical operators :

a, b, c = int(input("Number1 =")), int(
    input("Number2 =")), int(input("Number3 ="))

if a != b and b != c and c != a:
    if a > b and a > c:
        print(a, "is biggest number")
    elif b > a and b > c:
        print(b, "is biggest number")
    elif c > b and c > a:
        print(a, "is biggest number")

elif a == b and c != a:
    if c > a:
        print(c, "is biggest number")
    else:
        print(a, "is biggest number")

elif b == c and a != b:
    if a > b:
        print(a, "is biggest number")
    else:
        print(b, "is biggest number")

elif c == a and b != c:
    if b > c:
        print(b, "is biggest number")
    else:
        print(c, "is biggest number")
else:
    print("All numbers are equal")

# %%
# 29) The program should display a message indicating whether the person is an infant,
# a child, a teenager, or an adult. Following are the guidelines:

# •	If the person is 1 year old or less, he or she is an infant.
# •	If the person is older than 1 year, but younger than 13 years, he or she is a child.
# •	If the person is at least 13 years old, but less than 20 years old, he or she is a teenager.
# If the person is at least 20 years old, he or she is an adult.


a = int(input("Age (in years) ="))
if a <= 1:
    print("Infant")
elif a > 1 and a < 13:
    print("Child")
elif a >= 13 and a < 20:
    print("Teenager")
elif a >= 20:
    print("Adult")

# %%
# Q 34. Write a Python Program to find whether year is a leap year or not
n = int(input("enter the year"))
if n % 400 == 0 and n % 100 == 0:
    print(n, "is a leap year")
elif n % 4 == 0 and n % 100 != 0:
    print(n, "is a leap year")
else:
    print(n, "is not a leap year")

# %%
# Q 37. Write a program to compute Miles-per-Gallon
# expression: A car's miles-per-gallon (MPG) can be calculated with the following
# formula: MPG=Miles driven÷Gallons of gas used.
m = float(input("enter the no fo miles"))
g = float(input("enter the no of gallons"))
mpg = m/g
print(mpg, "the mpg of the car is")

# %%
# Q 39. Write a program in Python to find the simple interest
p = int(input("enter the principle"))
r = int(input("enter the rate"))
t = int(input("enter the time"))
si = (p*t*r)/100
print(si, "is the simple intrest ")

# %%
# 42) Write a program in Python to find whether the no is positive, negative or zero:

n = int(input())
if n < 0:
    print("Negative")
elif n == 0:
    print("Zero")
else:
    print("Positive")

# %%
# 44) Write a program in Python to find biggest of two nos:

m, n = int(input()), int(input())
if m != n:
    if m > n:
        print(m, "is biggest")
    else:
        print(n, "is biggest")
else:
    print("Both are equal")

# %%
# 45) Write a program in Python to find the smallest of two nos:

m, n = int(input()), int(input())
if m != n:
    if m < n:
        print(m, "is smallest")
    else:
        print(n, "is smallest")
else:
    print("Both are equal")

# %%
# 46) Write a program in Python to find smallest of three nos:

a, b, c = int(input()), int(input()), int(input())
if a != b and b != c and c != a:
  if a < b and a < c:
    print(a, "is smallest")
  elif b < c and b < a:
    print(b, "is smallest")
  elif c < a and c < b:
    print(c, "is smallest")
elif a == b and c != a:
  if c < a:
    print(c, "is smallest")
  else:
    print(a, "is smallest")
elif b == c and a != b:
  if a < b:
    print(a, "is smallest")
  else:
    print(b, "is smallest")
elif c == a and b != c:
  if b < c:
    print(b, "is smallest")
  else:
    print(c, "is smallest")
else:
  print("All numbers are equal")

# ----------------------------------------Or else--------------------------------------------------

print(min(a, b, c), "is smallest(using min function)")

# %%
# 64) Write a program to convert Celsius to Fahrenheit. F = (9/5) C+32 :

C = float(input("Temperature in celsius="))
F = ((9/5)*C)+35
print("Temperature in fahrenheit=", F)

# %%
# 65) Write a program in Python to convert Fahrenheit to Celsius. C = (F − 32) x 5/9 :

F = float(input("Temperature in fahrenheit="))
C = (F-32)*(5/9)
print("Temperature in celcius=", C)

# %%
# 69) The area of a rectangle is the rectangle’s length times its width. Write a program in Python that
#    asks for the length and width of two rectangles.The program should tell the user
#    which rectangle has the greater area, or if the areas are the same.

a, b = int(input("Length of first rectangle=")), int(
    input("Breadth of first rectangle="))
print("")
x, y = int(input("Length of second rectangle=")), int(
    input("Breadth of second rectangle="))
print("")
if a*b == x*y:
    print("=> Both areas are equal")
elif a*b > x*y:
    print("=> Area of first rectangle is greater")
else:
    print("=> Area of second rectange is greater")
